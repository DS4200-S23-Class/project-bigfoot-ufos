# %%
import pandas as pd

# %%
df = pd.read_csv("data/bigfoot.csv")

# %%
df
# Out:
#                                               observed  \
# 0    At 3:45 in the morning on Shi Shi Beach N., my...
# 1    I was accompanied by my wife and 15-yo son. We...
# 2    The sighting was the creature crossing the LaP...
# 3    My husband was driving while we were heading n...
# 4    My name is Tim. My wife Nan and I live between...
# ..                                                 ...
# 955  I have seen footprints of what I believe is a ...
# 956  Had a sighting yesterday. Oxford County, Maine...
# 957  It was a picture captured on a trail camera. I...
# 958  I was not in any way aware that these creature...
# 959  Background:  I have spent a large part of my l...
#
#                                       location_details               county  \
# 0    Directions to the site: Drive through Neah Bay...       Clallam County
# 1    On June 22, 2020; I was parked just outside th...       Clallam County
# ...

# %%
df['month']df['date']
# Out:
# 0       8/25/10
# 1       6/30/20
# 2        9/4/11
# 3        6/2/12
# 4       2/25/17
#          ...
# 955     2/27/16
# 956     9/26/20
# 957     1/30/16
# 958    10/19/20
# 959    11/12/20
# Name: date, Length: 960, dtype: object
